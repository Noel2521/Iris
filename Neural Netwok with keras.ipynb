# %% [markdown]
# ### Neural Network with Keras
#
# We'll create a simple neural network to classify the famous Iris dataset. This dataset is a classic in the machine learning world, often used for testing out machine learning algorithms in pattern recognition. It contains 3 classes of 50 instances each, where each class refers to a type of iris plant. Each instance has 4 attributes: sepal length, sepal width, petal length, and petal width.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.datasets import load_iris
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#Load the dataset 
iris = load_iris()
X, y = iris.data, iris.target

#Preporcessing the data
#Scale the feature
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

#One hot encoding targets 
encoder  = OneHotEncoder(sparse=True)
y_encoded = encoder.fit_transform(y.reshape(-1, 1)).toarray()

#Spliting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)


#Building the model
model = Sequential([
    Dense(10, activation='relu', input_shape=(4,)),  # Make sure input_shape matches your feature dimension
    Dense(3, activation='softmax')  # This is correct for a 3-class problem
])
print(model.summary())

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

#Evaluate the model on the test dataset
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}, Test_accuracy: {accuracy}")
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 10)                50
#
#  dense_17 (Dense)            (None, 3)                 33
#
# =================================================================
# Total params: 83 (332.00 Byte)
# Trainable params: 83 (332.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# None
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 11/11 [==============================] - 2s 4ms/step - loss: 1.1936 - accuracy: 0.1238
# Epoch 2/50
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1388 - accuracy: 0.1333
# Epoch 3/50
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0845 - accuracy: 0.2762
# Epoch 4/50
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0360 - accuracy: 0.4381
# Epoch 5/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9875 - accuracy: 0.5048
# Epoch 6/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9436 - accuracy: 0.5524
# Epoch 7/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9028 - accuracy: 0.6286
# Epoch 8/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8643 - accuracy: 0.6667
# Epoch 9/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.8277 - accuracy: 0.7048
# Epoch 10/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7926 - accuracy: 0.7810
# Epoch 11/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.7610 - accuracy: 0.8000
# Epoch 12/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7308 - accuracy: 0.8190
# Epoch 13/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7027 - accuracy: 0.8190
# Epoch 14/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.8190
# Epoch 15/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.8190
# Epoch 16/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6308 - accuracy: 0.8190
# Epoch 17/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.8190
# Epoch 18/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5908 - accuracy: 0.8190
# Epoch 19/50
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5729 - accuracy: 0.8190
# Epoch 20/50
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5564 - accuracy: 0.8190
# Epoch 21/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5405 - accuracy: 0.8190
# Epoch 22/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5258 - accuracy: 0.8190
# Epoch 23/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5121 - accuracy: 0.8190
# Epoch 24/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4990 - accuracy: 0.8190
# Epoch 25/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4866 - accuracy: 0.8190
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4757 - accuracy: 0.8190
# Epoch 27/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4651 - accuracy: 0.8190
# Epoch 28/50
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4551 - accuracy: 0.8190
# Epoch 29/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4456 - accuracy: 0.8190
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4372 - accuracy: 0.8190
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4285 - accuracy: 0.8190
# Epoch 32/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8190
# Epoch 33/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.8190
# Epoch 34/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4056 - accuracy: 0.8190
# Epoch 35/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3985 - accuracy: 0.8190
# Epoch 36/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3920 - accuracy: 0.8190
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3856 - accuracy: 0.8381
# Epoch 38/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3795 - accuracy: 0.8381
# Epoch 39/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3737 - accuracy: 0.8381
# Epoch 40/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.3683 - accuracy: 0.8381
# Epoch 41/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3628 - accuracy: 0.8476
# Epoch 42/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3582 - accuracy: 0.8381
# Epoch 43/50
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3529 - accuracy: 0.8571
# Epoch 44/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3484 - accuracy: 0.8571
# Epoch 45/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3442 - accuracy: 0.8571
# Epoch 46/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3394 - accuracy: 0.8571
# Epoch 47/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3353 - accuracy: 0.8571
# Epoch 48/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3311 - accuracy: 0.8571
# Epoch 49/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3269 - accuracy: 0.8571
# Epoch 50/50
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3229 - accuracy: 0.8571
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2909 - accuracy: 0.8444
# Test loss: 0.2908606231212616, Test_accuracy: 0.8444444537162781
